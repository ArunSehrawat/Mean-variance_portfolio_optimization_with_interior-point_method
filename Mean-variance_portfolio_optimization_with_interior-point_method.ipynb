# %%
import numpy as np
import matplotlib.pyplot as plt
import time, copy, random, warnings


import yfinance as yf                 #!pip install yfinance

# %% [markdown]
# # select asset

# %%
ticker_strings = 'AAL AAPL ABEV ACI AEO AFRM AMC AMD APA AQN AR ATVI AUY BA BABA BAC BB BBD BCRX BEKE BHC BILI BKR BMY BP BTG BTI C CCL CHPT CIG CIT CLF CMCSA COTY CPG CPNG CRM CSCO CSX CVE CVS CVX DAL DIDI DKNG DVN DWAC EDU EQT ET EXC F FB FCX FTI FUBO GGB GM GOLD GPS GRAB HAL HBAN HOOD HPE IBM INFY INTC IQ ITUB JD JPM KEY KGC KMI KO KOS KR LAC LCID LI LU LUMN LVS LYG M MARA MO MRK MRO MRVL MSFT MTTR MU NCLH NIO NKE NKLA NLY NOK NU NVDA ONON OPEN OTLY OXY PACB PBR PBR-A PCG PDD PFE PG PINS PLTR PLUG PTON PYPL QCOM QS RBLX RF RIG RIOT RIVN RYCEY SAN SBUX SE SIRI SKLZ SLB SNAP SOFI SPCE SQ SU SWN T TAL TCOM TLRY TME TSLA TSM TTWO TWTR UAL UBER V VALE VIAC VIPS VORB VTRS VZ WFC WMB X XOM XPEV YMM ZIM ZNGA'
ticker_list = ticker_strings.split()
print(len(ticker_list))


#np.random.seed(5)
assets = random.sample(ticker_list, 40)
#assets = ["AAPL", "MSFT", "AMZN","GOOGL", "V", "^IXIC", "BB", "CSCO", "GOLD", "NKE", "AMD", "EXC"]
# Out:
# 165

# %% [markdown]
# # asset prices downloading ...

# %%
start_date = "2010-01-01"
end_date = "2022-01-01"


prices = yf.download(assets, start=start_date, end=end_date)['Adj Close']
prices = prices.dropna(axis=1)                    # axis=1,0 : Drop columns,rows which contain missing value.
prices = prices.sort_values(by='Date')

assets = prices.columns.values.tolist()           # assets for which prices are downloaded

fontsize = 18
plt.plot(prices)
plt.ylabel('price',fontsize=fontsize)
plt.show()



prices
# Out:
# [*********************100%***********************]  40 of 40 completed
#                   AEO        BMY         BP        BTI       CIG      CMCSA  \
# Date
# 2009-12-31  10.659755  16.728951  29.412718  16.296398  2.886609   6.547668
# 2010-01-04  10.703703  16.980715  30.011436  16.435005  2.945748   6.627732
# 2010-01-05  11.042706  16.715702  30.224531  16.417362  2.995296   6.537904
# 2010-01-06  11.023866  16.709078  30.381817  16.364435  2.961731   6.491035
# 2010-01-07  10.684869  16.722330  30.371666  16.475334  2.893002   6.627732
# ...               ...        ...        ...        ...       ...        ...
# 2021-12-27  23.452837  60.413647  26.263720  34.971699  2.168966  49.167557
# 2021-12-28  23.735521  60.471840  26.195980  35.132427  2.196421  49.206520
# 2021-12-29  25.158676  60.413647  26.118565  35.274239  2.150662  49.284462
# 2021-12-30  25.119688  60.636719  25.828253  35.217510  2.187270  49.284462
# 2021-12-31  24.681042  60.471840  25.770189  35.368782  2.223876  49.031170
#
#                   CPG         CRM       CSCO         CVS  ...       NOK  \
# Date                                                      ...
# 2009-12-31  27.709454   18.442499  17.000511   24.806587  ...  8.458992
# 2010-01-04  27.960085   18.705000  17.533112   25.399609  ...  8.788135
# 2010-01-05  27.812654   18.625000  17.454990   25.299482  ...  8.722306
# 2010-01-06  28.277050   18.592501  17.341372   25.076145  ...  8.656477
# 2010-01-07  27.746311   18.510000  17.419487   26.000322  ...  8.768385
# ...               ...         ...        ...         ...  ...       ...
# 2021-12-27   5.128971  258.299988  61.489910  100.744537  ...  6.313583
# 2021-12-28   5.306513  255.449997  61.596569  101.108559  ...  6.273750
# 2021-12-29   5.128971  254.539993  62.013481  102.023514  ...  6.263792
# 2021-12-30   5.148698  255.330002  61.683830  102.003838  ...  6.233917
# 2021-12-31   5.267059  254.130005  61.441437  101.492256  ...  6.194083
#
#                   OXY      PBR-A          PG        SBUX        SLB  \
# Date
# 2009-12-31  52.230953  33.440025   41.399155    9.313449  48.049904
# 2010-01-04  53.354549  34.576008   41.733746    9.309411  49.541069
# 2010-01-05  52.969322  34.244675   41.747410    9.527509  49.681347
# 2010-01-06  53.604935  34.560226   41.549381    9.458847  50.788628
# 2010-01-07  53.206886  34.008022   41.324039    9.434615  51.312759
# ...               ...        ...         ...         ...        ...
# 2021-12-27  29.454357  10.180000  159.168091  112.209633  29.503149
# 2021-12-28  29.295359  10.210000  160.023026  113.535858  29.770102
# 2021-12-29  29.076736   9.990000  161.349686  114.331604  29.315294
# 2021-12-30  28.788551  10.170000  159.954254  114.194069  29.483376
# 2021-12-31  28.808428  10.110000  160.750244  114.911224  29.611910
#
#                    SU         TSM          X        XOM
# Date
# 2009-12-31  24.892879    7.553656  49.878342  41.748661
# 2010-01-04  25.915096    7.646097  52.403015  42.336411
# 2010-01-05  26.274635    7.613082  52.330639  42.501701
# 2010-01-06  26.796335    7.586669  54.656212  42.869049
# 2010-01-07  26.443830    7.335762  55.117737  42.734352
# ...               ...         ...        ...        ...
# 2021-12-27  24.248793  120.788132  23.562471  60.007713
# 2021-12-28  24.229401  120.158104  23.264339  59.813797
# 2021-12-29  23.967617  119.518242  23.145086  59.290222
# 2021-12-30  23.948227  118.543663  23.085459  58.941174
# 2021-12-31  24.268185  118.435371  23.661850  59.329006
#
# [3022 rows x 28 columns]

# %% [markdown]
# # asset retuns, covariance, and correlation
# for annual return, we take periods = trading days in a year = 252

# %%
                                                                           
retun_df = prices.pct_change(periods=252).dropna(how="all")                  # rate of return = [p_(t+1)-p_t]/p_t
#retun_df = np.log(1 + prices.pct_change(periods=252)).dropna(how="all")     # log_return


n = retun_df.shape[1]
print("number of assets = n =", n)  

assets_idx = 0
retun_df.T.iloc[assets_idx].hist(bins='auto')
plt.xlabel('rate of return',fontsize=fontsize )
plt.title(f"Histogram (distribution) of returns for asset {assets[assets_idx]}")  
# Histogram will look like a normal distribution if we take periods = 1
plt.show()


#------------------------------------------------------------------------------------

mu_df = retun_df.mean()                                      # expected return = sample mean
cov_df, corr_df = retun_df.cov(), retun_df.corr()            # expected risk = sample variance


cov_df.style.background_gradient()
# Out:
# number of assets = n = 28
# <style type="text/css">
# #T_ee0d1_row0_col0, #T_ee0d1_row1_col1, #T_ee0d1_row4_col4, #T_ee0d1_row4_col21, #T_ee0d1_row6_col3, #T_ee0d1_row6_col5, #T_ee0d1_row6_col6, #T_ee0d1_row6_col14, #T_ee0d1_row6_col23, #T_ee0d1_row6_col27, #T_ee0d1_row7_col7, #T_ee0d1_row13_col13, #T_ee0d1_row15_col15, #T_ee0d1_row16_col16, #T_ee0d1_row17_col9, #T_ee0d1_row17_col17, #T_ee0d1_row17_col19, #T_ee0d1_row18_col18, #T_ee0d1_row22_col22, #T_ee0d1_row26_col2, #T_ee0d1_row26_col8, #T_ee0d1_row26_col10, #T_ee0d1_row26_col11, #T_ee0d1_row26_col12, #T_ee0d1_row26_col20, #T_ee0d1_row26_col24, #T_ee0d1_row26_col25, #T_ee0d1_row26_col26 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col1, #T_ee0d1_row0_col10, #T_ee0d1_row18_col21, #T_ee0d1_row20_col5, #T_ee0d1_row25_col5 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col2, #T_ee0d1_row19_col5 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col3, #T_ee0d1_row3_col20, #T_ee0d1_row21_col7 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_ee0d1_row0_col4, #T_ee0d1_row5_col19, #T_ee0d1_row11_col18, #T_ee0d1_row14_col4, #T_ee0d1_row22_col8, #T_ee0d1_row22_col19, #T_ee0d1_row22_col23 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_ee0d1_row0_col5, #T_ee0d1_row23_col5 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col6, #T_ee0d1_row2_col8, #T_ee0d1_row4_col22, #T_ee0d1_row15_col22, #T_ee0d1_row20_col13, #T_ee0d1_row22_col5 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col7, #T_ee0d1_row6_col1, #T_ee0d1_row11_col10, #T_ee0d1_row11_col21, #T_ee0d1_row19_col9 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col8, #T_ee0d1_row11_col4 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col9, #T_ee0d1_row23_col9, #T_ee0d1_row27_col14 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col11, #T_ee0d1_row25_col9 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_ee0d1_row0_col12, #T_ee0d1_row16_col2, #T_ee0d1_row25_col1 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col13, #T_ee0d1_row8_col20, #T_ee0d1_row12_col4, #T_ee0d1_row12_col25, #T_ee0d1_row20_col18, #T_ee0d1_row22_col15, #T_ee0d1_row23_col25, #T_ee0d1_row27_col20 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_ee0d1_row0_col14, #T_ee0d1_row6_col8 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col15, #T_ee0d1_row1_col4, #T_ee0d1_row1_col6, #T_ee0d1_row1_col10, #T_ee0d1_row1_col11, #T_ee0d1_row1_col20, #T_ee0d1_row1_col26, #T_ee0d1_row2_col25, #T_ee0d1_row4_col7, #T_ee0d1_row8_col3, #T_ee0d1_row13_col0, #T_ee0d1_row13_col2, #T_ee0d1_row13_col5, #T_ee0d1_row13_col6, #T_ee0d1_row13_col8, #T_ee0d1_row13_col9, #T_ee0d1_row13_col12, #T_ee0d1_row13_col16, #T_ee0d1_row13_col17, #T_ee0d1_row13_col18, #T_ee0d1_row13_col19, #T_ee0d1_row13_col22, #T_ee0d1_row13_col23, #T_ee0d1_row13_col24, #T_ee0d1_row13_col27, #T_ee0d1_row17_col13, #T_ee0d1_row17_col21, #T_ee0d1_row18_col14, #T_ee0d1_row20_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ee0d1_row0_col16, #T_ee0d1_row20_col24, #T_ee0d1_row27_col22 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col17, #T_ee0d1_row26_col17 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col18, #T_ee0d1_row3_col4, #T_ee0d1_row10_col3, #T_ee0d1_row10_col11, #T_ee0d1_row27_col26 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_ee0d1_row0_col19, #T_ee0d1_row24_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col20, #T_ee0d1_row1_col17, #T_ee0d1_row5_col12, #T_ee0d1_row8_col4, #T_ee0d1_row8_col27, #T_ee0d1_row10_col23, #T_ee0d1_row14_col8, #T_ee0d1_row16_col6, #T_ee0d1_row21_col18, #T_ee0d1_row22_col4, #T_ee0d1_row23_col11 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_ee0d1_row0_col21 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_ee0d1_row0_col22, #T_ee0d1_row20_col11 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col23, #T_ee0d1_row9_col22, #T_ee0d1_row16_col21, #T_ee0d1_row23_col27 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col24, #T_ee0d1_row21_col22, #T_ee0d1_row23_col15, #T_ee0d1_row25_col13, #T_ee0d1_row26_col15 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col25, #T_ee0d1_row6_col16, #T_ee0d1_row11_col8, #T_ee0d1_row18_col16, #T_ee0d1_row19_col27 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_ee0d1_row0_col26, #T_ee0d1_row2_col17, #T_ee0d1_row14_col3, #T_ee0d1_row20_col19, #T_ee0d1_row24_col18 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_ee0d1_row0_col27, #T_ee0d1_row5_col21, #T_ee0d1_row11_col26, #T_ee0d1_row14_col1 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_ee0d1_row1_col0, #T_ee0d1_row1_col24, #T_ee0d1_row26_col14 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_ee0d1_row1_col2, #T_ee0d1_row2_col0, #T_ee0d1_row3_col18, #T_ee0d1_row7_col12, #T_ee0d1_row11_col14, #T_ee0d1_row25_col4 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_ee0d1_row1_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_ee0d1_row1_col5, #T_ee0d1_row9_col17 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_ee0d1_row1_col7, #T_ee0d1_row18_col27, #T_ee0d1_row25_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_ee0d1_row1_col8, #T_ee0d1_row2_col11, #T_ee0d1_row8_col0, #T_ee0d1_row14_col15, #T_ee0d1_row25_col20 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_ee0d1_row1_col9, #T_ee0d1_row12_col8, #T_ee0d1_row23_col16, #T_ee0d1_row24_col24, #T_ee0d1_row26_col18 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_ee0d1_row1_col12, #T_ee0d1_row5_col10, #T_ee0d1_row14_col0, #T_ee0d1_row18_col6, #T_ee0d1_row19_col25 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_ee0d1_row1_col13, #T_ee0d1_row5_col13, #T_ee0d1_row5_col23, #T_ee0d1_row15_col19, #T_ee0d1_row17_col11, #T_ee0d1_row19_col20, #T_ee0d1_row20_col14, #T_ee0d1_row21_col4, #T_ee0d1_row24_col13, #T_ee0d1_row25_col17 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_ee0d1_row1_col14, #T_ee0d1_row2_col7, #T_ee0d1_row2_col13, #T_ee0d1_row10_col27, #T_ee0d1_row12_col10, #T_ee0d1_row12_col20, #T_ee0d1_row18_col10, #T_ee0d1_row24_col21 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_ee0d1_row1_col15, #T_ee0d1_row4_col12, #T_ee0d1_row4_col26, #T_ee0d1_row8_col7, #T_ee0d1_row14_col10, #T_ee0d1_row14_col23, #T_ee0d1_row19_col13, #T_ee0d1_row21_col17, #T_ee0d1_row25_col19 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_ee0d1_row1_col16, #T_ee0d1_row4_col13 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_ee0d1_row1_col18, #T_ee0d1_row5_col2, #T_ee0d1_row7_col18, #T_ee0d1_row8_col5, #T_ee0d1_row8_col19, #T_ee0d1_row10_col17, #T_ee0d1_row23_col0, #T_ee0d1_row27_col12 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_ee0d1_row1_col19, #T_ee0d1_row8_col11, #T_ee0d1_row10_col7, #T_ee0d1_row18_col4, #T_ee0d1_row25_col10 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_ee0d1_row1_col21, #T_ee0d1_row3_col16, #T_ee0d1_row4_col15 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_ee0d1_row1_col22, #T_ee0d1_row16_col23, #T_ee0d1_row16_col24, #T_ee0d1_row24_col14, #T_ee0d1_row26_col3, #T_ee0d1_row27_col3 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_ee0d1_row1_col23, #T_ee0d1_row8_col14, #T_ee0d1_row13_col10, #T_ee0d1_row20_col0, #T_ee0d1_row21_col10, #T_ee0d1_row25_col26, #T_ee0d1_row26_col21 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_ee0d1_row1_col25, #T_ee0d1_row4_col25, #T_ee0d1_row7_col26, #T_ee0d1_row9_col26, #T_ee0d1_row10_col25, #T_ee0d1_row15_col0, #T_ee0d1_row20_col7 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_ee0d1_row1_col27, #T_ee0d1_row16_col13, #T_ee0d1_row16_col25, #T_ee0d1_row22_col12 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_ee0d1_row2_col1, #T_ee0d1_row14_col22 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_ee0d1_row2_col2 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_ee0d1_row2_col3, #T_ee0d1_row4_col17, #T_ee0d1_row5_col15, #T_ee0d1_row8_col12 {
#   background-c

# %% [markdown]
# # $ $
#
# # mean-variance portfolio optimization
#
# We want at least return $R\in[\min(\mu), \max(\mu)]$ from our portfolio, so the optimization task is
#
#
# $\text{min}\ x^T \Sigma x $
#
# $\text{such that}\ x \succeq \textbf{0},\ \mu^T x \geq R,\ $ and $\ \textbf{1}^T x  = 1.$
#
# $ $
#
# $\preceq$ and $\succeq$ are componentwise vector inequalities.
# $\Sigma = \text{covariance matrix},$
# $\mu = \text{expected return vector},$
# $\textbf{1}$ is a column vector of 1s,
# and $x$ is a vector of portfolio weights.
#
#
# $ $

# %%
min_mu = np.min(mu_df)
max_mu = np.max(mu_df)


R = (max_mu + min_mu)/2

print(f"min_mu = {round(min_mu,2)}")
print("R =", round(R,2))
print(f"max_mu = {round(max_mu,2)}\n")
                       
                                 
print(f"Is R in between min_mu and max_mu : {min_mu <= R<= max_mu} \n")

print(mu_df)
# Out:
# min_mu = -0.02
# R = 0.15
# max_mu = 0.32
#
# Is R in between min_mu and max_mu : True
#
# AEO      0.222602
# BMY      0.137460
# BP       0.033137
# BTI      0.076577
# CIG      0.071700
# CMCSA    0.213471
# CPG     -0.018300
# CRM      0.257850
# CSCO     0.129534
# CVS      0.132268
# EXC      0.064591
# GGB      0.071147
# JPM      0.183743
# KGC      0.022846
# KO       0.098604
# LVS      0.143884
# LYG      0.068056
# M        0.184239
# NOK      0.049937
# OXY      0.025930
# PBR-A    0.028163
# PG       0.117654
# SBUX     0.259193
# SLB      0.007526
# SU       0.029788
# TSM      0.319365
# X        0.174831
# XOM      0.055084
# dtype: float64

# %% [markdown]
# # portfolio return and risk, gradient and Hessian for minimization of the convex objective function with log-barrier to take care of inequality constraints
#
#
# $\text{minimize objective function}\ = f(x) = \ t\;(x^T \Sigma x) -[\textbf{1}^T\ln(x) + \ln(\mu^T x - R)] $
#
# $\text{such that}\ \textbf{1}^T x  = 1$
#
# $ $
#
# gradient $= \nabla f = 2\; t\; \Sigma\; x - \frac{1}{x} - \frac{1}{\mu^T x - R}\;\mu$
#
# Hessian $= \nabla^2 f = 2\; t\; \Sigma - \text{diag}(\frac{1}{x^2}) - \frac{1}{(\mu^T x - R)^2}\;\mu\mu^T$
#
#
#
# $\frac{1}{x}$ is the vector with components $\frac{1}{x_i}$ <br>
# $\text{diag}(\frac{1}{x^2})$ is the diagonal matrix with diagonal-entries $\frac{1}{x^2_i}$
#
# Parameter $t>0$ goes from 0 to $\infty$ to turn the inequality constraints from soft to hard.
#
# $ $

# %%
mu, cov, corr = mu_df.to_numpy(), cov_df.to_numpy(), corr_df.to_numpy()

ones = np.ones(n)
ones0 = np.append(ones, 0)


def portfolio_return(x):
    return (mu @ x)     

def portfolio_risk(x):
    return (x @ cov @ x)

def obj_fn(t, x):
    f = t*(x @ cov @ x) - (ones @ np.log(x) + np.log(portfolio_return(x)- R))
    return f


def grad(t, x):
    gr = 2*t*(cov @ x) -1/x -(1/(portfolio_return(x)- R))*mu
    return gr

def Hessian(t, x):
    hess = 2*t*cov + np.diag(1/(x*x)) + (1/(portfolio_return(x)- R)**2)*(mu.reshape(-1,1) @ mu.reshape(1,-1))
    return hess


def inequality_constraints(x):            
    c1 = min(x) >= 0
    c2 = portfolio_return(x) >= R
    c = c1&c2
    return c


def portfolio_perform(x):
    Return = portfolio_return(x)
    risk = np.sqrt(portfolio_risk(x))
    risk_free_rate = 0.02                            # risk_free_rate is taken 2%
    
    print(f"portfolio annual return = {100*Return:.1f} %")
    print(f"portfolio annual volatility = {100*risk:.1f} %")
    print(f"shapr ratio = {(Return-risk_free_rate)/risk:.2f}")

# %% [markdown]
# # generateing an initial feasible (interior-point) solution: x_in

# %%
indices = np.where(mu>=R)[0]
print(f'indices of assets that give more return than the desired R = {indices}')


'''if there is only asset that gives more return than the desired R, 
then no optimization needed and the whole portfolio will be made of that asset only'''


#----------------------------------------------------------------------------

theta = 0.01

for i in range(300):
    x_in = np.zeros(n)
    x_in[indices]=np.random.rand(len(indices))
    
    x_in = x_in + theta*np.random.rand(n)   
    x_in = x_in/np.linalg.norm(x_in, 1)

    if portfolio_return(x_in) >= R:
        break
        

if inequality_constraints(x_in)==False or round(x_in.sum(),5)!=1:
    warnings.warn('infeasible initial solution. change theta or/and run it again')         



# obj_fn(0.5, x_in), grad(0.5, x_in), Hessian(0.5, x_in)
# Out:
# indices of assets that give more return than the desired R = [ 0  5  7 12 17 22 25 26]

# %% [markdown]
# # Iterations for Newton's method
#
# center path $t_k = t_\text{in}\alpha^{k}$ for iterations $k = 0, 1, 2,\cdots $
#
# in $k$th iteration $x_{k+1} = x_k + \Delta x\qquad$         where
# $
# \begin{pmatrix}
# \Delta x \\
# \nu
# \end{pmatrix}
#  =
# \begin{pmatrix}
# \nabla^2 f & \textbf{1} \\
# \textbf{1}^T & 0
# \end{pmatrix}^{-1}
# \begin{pmatrix}
# -\nabla f \\
# 0
# \end{pmatrix}
# $
#
# for more details see the book "Convex Optimization" by Boyd and Vandenberghe.

# %%
'''
one can use cvxopt [given in the end] for faster and better convergence
here one must tune hyperparameters Itrs, t_in, alpha
'''



Itrs = 50             # total Iterations

t_in = 0.1                 # must be > 0
alpha = 2           # must be > 1
t = t_in

#--------------Initialization----------------------

Sol = [x_in]                                                    # solution at different iterations
Fn = [obj_fn(t_in, x_in)]                                       # objective function value at different iterations
Rtn = [portfolio_return(x_in)]                                  # return at different iterations
Rsk = [portfolio_risk(x_in)]                                    # risk at different iterations
Consts = [[inequality_constraints(x_in), round(x_in.sum(),5)]]  # Constraints at different iterations



time_start = time.time()                                        # Start the stopwatch


#---------------------------------------------------

for k in range(Itrs): 
    
    t= alpha*t                   # we are increasing t in every itr by multiplying it with alpha > 1
    x = Sol[-1]
    
    #-----------------------------------------------------------------------------
    Hess1 = np.append(np.append(Hessian(t, x), ones.reshape(1,-1), axis=0).T, ones0.reshape(1,-1), axis=0)
    Hess1_inv = np.linalg.inv(Hess1)
    
    Grad0 = np.append(-grad(t, x), 0)
    
    dx_nu = Hess1_inv @ Grad0
    x = x + dx_nu[:-1]          # dx = dx_nu[:-1]
    
 
    if inequality_constraints(x)==False:
        print(f"iteration = {k}" )
        break
    
    #-----------------------------------------------------------------------------
    risk = portfolio_risk(x)
    
    Sol.append(x)
    Fn.append(obj_fn(t, x))
    Rtn.append(portfolio_return(x))
    Rsk.append(risk)
    Consts.append([inequality_constraints(x), round(x.sum(),5)])
    
    #-----------------------------------------------------------------------------
    
    if k % 10 == 0: 
        print(f"iteration = {k}   risk = {round(risk,2)}" )



time_taken = time.time()  - time_start                  # Stop the stopwatch 
print("time taken in sec. = ", time_taken)


#=================================================================================


plt.plot(Rsk, color='red')          # Risk must decrease
plt.ylabel('Risk')
plt.title(f"t_in = {t_in} , alpha = {alpha}")
plt.show()

plt.plot(Rtn)
plt.plot(R*np.ones(len(Rtn)))
plt.title(f"Return >= R = {R}")   # Return must be above the value R
plt.ylabel('Return')
plt.xlabel('Iterations')
plt.show()


np.where(np.array(Consts)!=1)  # empty means no equality or inequality constraint got violated
# Out:
# iteration = 0   risk = 0.07
# iteration = 10   risk = 0.02
# iteration = 20   risk = 0.0
# iteration = 30   risk = 0.0
# iteration = 40   risk = 0.0
# time taken in sec. =  0.02391362190246582
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# # optimized portfolio

# %%
x_sol = Sol[-1]


plt.rcParams["figure.figsize"] = (6,6)
plt.pie(x_sol, normalize=True, labels=assets)  
plt.show()

print(f'solution = {np.round(x_sol, 5)}\n' )
portfolio_perform(x_sol)
# Out:
# solution = [0.      0.13485 0.      0.      0.      0.02677 0.      0.14034 0.11524
#  0.02802 0.08625 0.      0.      0.03505 0.21876 0.      0.      0.
#  0.      0.      0.      0.10476 0.06518 0.      0.      0.04478 0.
#  0.     ]
#
# portfolio annual return = 15.1 %
# portfolio annual volatility = 7.0 %
# shapr ratio = 1.87

# %% [markdown]
# # portfolio optimization with pypfopt
#
# $ $

# %%
# https://pyportfolioopt.readthedocs.io/en/latest/index.html

from pypfopt.efficient_frontier import EfficientFrontier

ef = EfficientFrontier(mu_df, cov_df)
weights = ef.efficient_return(target_return=R, market_neutral=False)


ef.portfolio_performance(verbose=True)

weights
# Out:
# Expected annual return: 15.1%
# Annual volatility: 7.0%
# Sharpe Ratio: 1.87
# OrderedDict([('AEO', 0.0),
#              ('BMY', 0.1348524155737554),
#              ('BP', 0.0),
#              ('BTI', 0.0),
#              ('CIG', 0.0),
#              ('CMCSA', 0.026770322829535),
#              ('CPG', 0.0),
#              ('CRM', 0.1403368324416226),
#              ('CSCO', 0.1152358939638065),
#              ('CVS', 0.0280200250832961),
#              ('EXC', 0.0862518773340288),
#              ('GGB', 0.0),
#              ('JPM', 0.0),
#              ('KGC', 0.0350522572558797),
#              ('KO', 0.2187615348307484),
#              ('LVS', 0.0),
#              ('LYG', 0.0),
#              ('M', 0.0),
#              ('NOK', 0.0),
#              ('OXY', 0.0),
#              ('PBR-A', 0.0),
#              ('PG', 0.1047639066370252),
#              ('SBUX', 0.0651777951481718),
#              ('SLB', 0.0),
#              ('SU', 0.0),
#              ('TSM', 0.0447771389021306),
#              ('X', 0.0),
#              ('XOM', 0.0)])

# %% [markdown]
# # cvxopt solver for quadratic programming (portfolio optimization)
#
#
#
# $\text{min}\ \frac{1}{2}x^T P x + q^T x$
#
# $\text{such that}\ Gx \preceq h$ and $ Ax = b$

# %%
# https://cvxopt.org/

from cvxopt import matrix, solvers
from cvxopt.solvers import qp

q = matrix(np.zeros((n,1)))         # a CVXOPT matrix can be created from a Numpy array


G = np.identity(n)
G = -1*np.append(G, mu.reshape(1,-1), axis=0)
G = matrix(G)

h = np.zeros(n)
h = -1*np.append(h, R).reshape(-1,1)
h = matrix(h)

A = matrix(np.ones((1,n))) 
b = matrix(1.0)

#----------------------------------------------------------

sol = qp(matrix(2*cov), q, G, h, A, b)
x_sol_cvxopt = np.array(sol['x'])  # give Numpy array


print(f"\n x_sol_cvxopt = {np.round(x_sol_cvxopt.flatten(),4)}")
# Out:
#      pcost       dcost       gap    pres   dres
#  0:  8.5260e-03 -9.8186e-01  3e+01  6e+00  6e+00
#  1:  1.7847e-02 -9.0183e-01  1e+00  9e-02  1e-01
#  2:  2.0531e-02 -9.0957e-02  1e-01  1e-03  1e-03
#  3:  1.2460e-02 -6.4619e-03  2e-02  1e-04  2e-04
#  4:  6.9072e-03  3.0595e-03  4e-03  2e-06  2e-06
#  5:  5.3020e-03  4.4734e-03  8e-04  1e-07  1e-07
#  6:  4.9295e-03  4.8734e-03  6e-05  2e-09  2e-09
#  7:  4.8942e-03  4.8899e-03  4e-06  1e-10  1e-10
#  8:  4.8910e-03  4.8908e-03  1e-07  9e-13  1e-12
#  9:  4.8909e-03  4.8909e-03  2e-09  9e-15  2e-14
# Optimal solution found.
#
#  x_sol_cvxopt = [0.     0.1348 0.     0.     0.     0.0268 0.     0.1403 0.1152 0.028
#  0.0863 0.     0.     0.0351 0.2188 0.     0.     0.     0.     0.
#  0.     0.1048 0.0652 0.     0.     0.0448 0.     0.    ]
